# %%
import numpy as np
from scipy.misc import imread
import matplotlib.pyplot as plt

def imkernel(tau, s1, s2):
    w = lambda i,j:np.exp(-(i**2+j**2)/(2*tau**2))
    # normalization
    i,j=np.mgrid[-s1:s1,-s2:s2]
    Z = np.sum(w(i,j))
    nu = lambda i,j: w(i,j)/Z*(np.absolute(i)<= s1&np.absolute(j)<=s2)
    
    return nu

# Create imconvolve_naive function,
def imconvolve_naive(im, nu, s1, s2):
    (n1,n2)=im.shape
    win_size=(s1,s2)
    xconv = np.zeros((n1,n2))
    '''
    Your code here
    '''
    for i in range (s1,n1-s1):
        for j in range(s2,n2-s2):
            sum=0
            for k in range(-s1,s1+1):
                for l in range(-s2,s2+1):
                    sum=sum+nu(k,l)*im[i-k,j-l]
            xconv[i,j]=sum
    return xconv

#Create imconvolve_spatial function
def imconvolve_spatial(x, nu,s1,s2):
    '''
    Your code here
    '''
    
    return xconv

#Create imconvolve_spatial function
def imconvolve_spatial(im,nu, s1,s2):
    '''
    Your code here
    '''
    (n1,n2)=im.shape
    win_size=(s1,s2)
    xconv = np.zeros((n1,n2))
    a=np.zeros((1,n2))
    b=np.zeros((n1+2*s1,1))
    p=0
    while p<s1:
        img=np.row_stack((a,img))
        p=p+1
    while q<s
    
    
    return xconv

#Sample call and Plotting code
tau = 1
s1 = 4
s2 = 4
'''
Your code here
'''
im=imread('windmill.png')
I_love_overseas_project=imconvolve_naive(im, nu, s1, s2)
plt.imshow(I_love_overseas_project,cmap='gray')
plt.show()
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:52: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
import numpy as np
from scipy.misc import imread
import matplotlib.pyplot as plt
import time

def imkernel(tau, s1, s2):
    w = lambda i,j:np.exp(-(i**2+j**2)/(2*tau**2))
    # normalization
    i,j=np.mgrid[-s1:s1,-s2:s2]
    Z = np.sum(w(i,j))
    nu = lambda i,j: w(i,j)/Z*(np.absolute(i)<= s1&np.absolute(j)<=s2)
    
    return nu

# Create imconvolve_naive function,
def imconvolve_naive(im, nu, s1, s2):
    (n1,n2)=im.shape
    win_size=(s1,s2)
    xconv = np.zeros((n1,n2))
    '''
    Your code here
    '''
    for i in range (s1,n1-s1):
        for j in range(s2,n2-s2):
            sum=0
            for k in range(-s1,s1+1):
                for l in range(-s2,s2+1):
                    sum=sum+nu(k,l)*im[i-k,j-l]
            xconv[i,j]=sum
    return xconv

#Create imconvolve_spatial function
def imconvolve_spatial(im,nu, s1,s2):
    n1,n2=np.shape(im)
    xconv=np.zeros((n1,n2))
    for k in range(-s1,s1+1):
        for l in range(-s2, s2+1):
            xshift=imshift(im, -k, -l)
            xconv+=nu(k,l)*xshift    
    return xconv

#Sample call and Plotting code

tau = 1
s1 = 4
s2 = 4
'''
Your code here
'''
nu=imkernel(tau, s1, s2)
im=imread('windmill.png')
original=im
plt.subplot(1,3,1)
plt.imshow(original,cmap='gray')
Naive=imconvolve_naive(im, nu, s1, s2)
plt.subplot(1,3,2)
plt.imshow(Naive,cmap='gray')
Spatial_ZP=imconvolve_spatial(im,nu,s1,s2)
plt.subplot(1,3,3)
plt.imshow(Spatial_ZP,cmap='gray')
plt.show()


start1=time.time()
imconvolve_naive(im, nu, s1, s2)
end1=time.time()
print(str(end1))


start2=time.time()
imconvolve_spatial(im,nu, s1,s2)
end2=time.time()
print(str(end2))

str(end2)>str(end1)
#the result shows that imconvolve_spatial function spends more time because it considers around boundaries.
#I didn't use the method as what the question requires to build imconvolve_spatial function.
# Out:
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:76: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# 1570947204.4345784
# 1570947204.4485412
# True
